# %% [markdown]
# <a href="https://colab.research.google.com/github/laraagasii/DIF62130_B_24-25_2311531002_HanifahLaramaAgasi/blob/main/Praktikum1/SimpleLinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {'luas' : [6, 8, 10, 14, 18],
        'harga' : [7, 9, 13, 17.5, 18]}
df = pd.DataFrame(data)
df
# Out:
#    luas  harga
# 0     6    7.0
# 1     8    9.0
# 2    10   13.0
# 3    14   17.5
# 4    18   18.0

# %% [markdown]
# **Import Library**
#
# 1. pandas adalah library Python yang digunakan untuk manipulasi dan analisis data.
# 2. pd adalah alias yang umum digunakan untuk mempersingkat penulisan.
#
# **Membuat Data dalam Bentuk Dictionary**
#
# 1. Dictionary (data) dibuat dengan dua kunci:
#
# *   'luas' berisi daftar angka [6, 8, 10, 14, 18], yang merepresentasikan ukuran atau luas suatu objek (misalnya luas tanah atau rumah).
# *   'harga' berisi daftar angka [7, 9, 13, 17.5, 18], yang dapat merepresentasikan harga dari objek dengan luas yang bersesuaian.
#
# 2. Data ini terdiri dari dua kolom dengan masing-masing lima baris.
#
# **Membuat DataFrame dari Dictionary**
#
# 1. pd.DataFrame(data) mengubah dictionary data menjadi DataFrame, yaitu struktur data berbentuk tabel yang lebih mudah dianalisis.
# 2. df adalah variabel yang menyimpan DataFrame tersebut.
#
# **Menampilkan DataFrame**
#
# 1. Kode ini menampilkan isi df dalam bentuk tabel ketika dijalankan di lingkungan seperti Jupyter Notebook atau Google Colab.
# 2. Output yang ditampilkan akan berbentuk tabel

# %%
import matplotlib.pyplot as plt

df.plot(kind='scatter', x='luas', y='harga')
plt.title('Perbandingan Luas Tanah dengan Harga Tanah')
plt.xlabel('Luas Tanah (m persegi)')
plt.ylabel('Harga Tanah (dollar)')
plt.xlim(0, 25)
plt.ylim(0, 25)
plt.grid(True)
plt.show()

# %% [markdown]
# 1. Import library matplotlib.pyplot sebagai plt.
# 2. Membuat scatter plot dari DataFrame df, dengan luas sebagai sumbu x dan harga sebagai sumbu y.
# 3. Menambahkan judul & label sumbu.
# 4. Mengatur batas sumbu (x: 0-25, y: 0-25).
# 5. Menampilkan grid & grafik dengan plt.grid(True) dan plt.show().

# %%
import numpy as np

X = np.array(df['luas'])     #Independent Variable (Features)
y = np.array(df['harga'])    #Dependent Variable (Target)

print(f'X: {X}')
print(f'y: {y}')
# Out:
# X: [ 6  8 10 14 18]
# y: [ 7.   9.  13.  17.5 18. ]

# %% [markdown]
# 1. Import NumPy sebagai np.
# 2. Mengonversi DataFrame ke NumPy array:
#
# *  X = np.array(df['luas']) → Fitur (Independent Variable)
# *  y = np.array(df['harga']) → Target (Dependent Variable)
#
# 3. Mencetak hasil array dengan print().

# %%
X = X.reshape(-1, 1)

print(f'X shape: {X.shape}')
print(f'X: {X}')
# Out:
# X shape: (5, 1)
# X: [[ 6]
#  [ 8]
#  [10]
#  [14]
#  [18]]

# %% [markdown]
# 1. X.reshape(-1, 1)
#
#
# *   Mengubah X dari (n,) (1D) menjadi (n,1) (2D).
# *   -1 berarti otomatis menyesuaikan jumlah baris, 1 menunjukkan satu kolom.
#
# 2. Mencetak bentuk dan isi X
#
#
# *   X.shape → Menampilkan dimensi array setelah reshape.
# *   X → Menampilkan array hasil reshape.

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# 1. Import library: Menggunakan LinearRegression dari scikit-learn untuk membuat model regresi linier.
#
# 2. Membuat model: Membuat objek model untuk regresi linier.
#
# 3. Melatih model:
#
#
# *   fit(X, y) menyesuaikan model dengan data (X sebagai luas tanah dan y sebagai harga tanah).
# *   Model akan mencari hubungan linear terbaik untuk memprediksi harga berdasarkan luas.

# %%
X_vis = np.array( [0,25]).reshape(-1, 1)
y_vis = model.predict(X_vis)

# %% [markdown]
# 1. Membuat data untuk visualisasi
#
#
# *   Membuat array NumPy berisi dua nilai [0, 25] sebagai titik referensi untuk prediksi.
# *   reshape(-1, 1) mengubah array menjadi bentuk (n,1) agar sesuai dengan model.
#
# 2. Memprediksi harga berdasarkan model: Menggunakan model regresi linier untuk memprediksi harga tanah berdasarkan nilai X_vis.

# %%
plt.scatter(X, y)
plt.plot(X_vis, y_vis, c='red')

plt.title('Perbandingan Luas Tanah dengan Harga Tanah')
plt.xlabel('Luas Tanah (m persegi)')
plt.ylabel('Harga Tanah (dollar)')
# plt.xlim(0, 25)
# plt.ylim(0, 25)
plt.grid(True)
plt.show()

# %% [markdown]
# 1. Menampilkan data asli: Membuat scatter plot (X = luas tanah, y = harga tanah).
#
# 2. Menampilkan garis regresi: Menggambar garis regresi berdasarkan prediksi model (X_vis, y_vis).
#
# 3. Menambahkan judul & label sumbu
#
# 4. Menampilkan grid & grafik
#
# 5. Menampilkan grid dan grafik scatter dengan garis regresi.

# %%
print(f'intercept: {model.intercept_}')
print(f'slope: {model.coef_}')
# Out:
# intercept: 1.965517241379315
# slope: [0.9762931]

# %% [markdown]
# 1. model.intercept_ → Nilai intercept, yaitu titik potong garis regresi dengan sumbu y (harga tanah saat luas = 0).
# 2. model.coef_ → Nilai slope, yaitu kemiringan garis regresi yang menunjukkan seberapa besar perubahan harga tanah untuk setiap peningkatan luas tanah.

# %%
luas_tanah = np.array([12, 15, 20]).reshape(-1,1)
print(luas_tanah.shape)
luas_tanah
# Out:
# (3, 1)
# array([[12],
#        [15],
#        [20]])

# %% [markdown]
# 1. reshape(-1,1) → Mengubah array 1D menjadi (n,1) untuk kompatibilitas dengan scikit-learn.
# 2. print(luas_tanah.shape) → Menampilkan bentuk array ((3,1), artinya 3 baris, 1 kolom).
# 3. luas_tanah → Menampilkan isi array setelah diubah bentuknya.

# %%
harga_prediksi = model.predict(luas_tanah)
harga_prediksi
# Out:
# array([13.68103448, 16.60991379, 21.49137931])

# %% [markdown]
# 1. model.predict(luas_tanah) → Menggunakan model yang telah dilatih untuk menghitung harga tanah berdasarkan nilai luas (12, 15, 20).
# 2. harga_prediksi → Berisi hasil prediksi harga tanah untuk setiap luas yang diberikan.

# %%
for luas, hrg in zip(luas_tanah, harga_prediksi):
  print(f'Luas Tanah: {luas}: Harga Prediksi: {hrg}')
# Out:
# Luas Tanah: [12]: Harga Prediksi: 13.681034482758621
# Luas Tanah: [15]: Harga Prediksi: 16.609913793103445
# Luas Tanah: [20]: Harga Prediksi: 21.491379310344826

# %% [markdown]
# 1. zip(luas_tanah, harga_prediksi) → Menggabungkan setiap pasangan luas tanah dengan harga prediksi.
# 2. Loop for → Iterasi setiap pasangan dan mencetak luas tanah beserta harga prediksinya.
# 3. F-string → Memformat output agar lebih rapi.

# %%
X_train = np.array([6, 8, 10, 14, 18]).reshape(-1, 1)
y_train = np.array([7, 9, 13, 17.5, 18])

X_test = np.array([9, 9, 11, 16, 12]).reshape(-1, 1)
y_test = np.array([11, 8.5, 15, 18, 11])

# %% [markdown]
# 1. X_train, y_train → Data training (fitur luas tanah & harga) digunakan untuk melatih model.
# 2. X_test, y_test → Data testing digunakan untuk mengukur performa model setelah dilatih.
# 3. reshape(-1,1) → Mengubah data X menjadi 2D array agar sesuai dengan model.

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# 1. model = LinearRegression() → Membuat model regresi linier.
# 2. model.fit(X_train, y_train) → Melatih model dengan data training untuk menemukan hubungan antara luas tanah (X_train) dan harga tanah (y_train).

# %%
from sklearn.metrics import r2_score

y_pred = model.predict(X_test)
r_squared = r2_score(y_test, y_pred)
print(f'R-Squared: {r_squared}')
# Out:
# R-Squared: 0.6873061136400747

# %% [markdown]
# 1. model.predict(X_test) → Memprediksi harga tanah berdasarkan data uji (X_test).
# 2. r2_score(y_test, y_pred) → Menghitung R-squared, yaitu seberapa baik model menjelaskan variasi dalam data.
# 3. print(f'R-Squared: {r_squared}') → Menampilkan nilai R².

# %%
y_pred
# Out:
# array([10.75215517, 10.75215517, 12.70474138, 17.5862069 , 13.68103448])

# %% [markdown]
# y_pred berisi hasil prediksi harga tanah berdasarkan X_test menggunakan model regresi linier.
